# %% [markdown]
# # API Call
# - Input file ('Resources/use_this_fortune_500.csv')
# - Output file ('Resources/fortune_coordinates_new.csv')

# %%
import time
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
import re

# %%
# Initialize Nominatim API
geolocator = Nominatim(user_agent="MyApp")

# %%
# Read in data
df = pd.read_csv('Resources/use_this_fortune_500.csv')
final_df = df.loc[df["year"]>= 2015]
final_df.reset_index(drop=True,inplace=True)
final_df.head(5)
# Out:
#                  name  rank  year                                  industry  \
# 0             Walmart     1  2015                     General Merchandisers
# 1         Exxon Mobil     2  2015                        Petroleum Refining
# 2             Chevron     3  2015                        Petroleum Refining
# 3  Berkshire Hathaway     4  2015  Insurance: Property and Casualty (Stock)
# 4               Apple     5  2015               Computers, Office Equipment
#
#        sector headquarters_state headquarters_city  market_value_mil  \
# 0   Retailing                 AR       Bentonville          265344.0
# 1      Energy                 TX            Irving          356549.0
# 2      Energy                 CA         San Ramon          197381.0
# 3  Financials                 NE             Omaha          357344.0
# 4  Technology                 CA         Cupertino          724773.0
#
#    revenue_mil  profit_mil  asset_mil  employees founder_is_ceo female_ceo  \
# 0     485651.0     16363.0   203706.0  2200000.0             no         no
# 1     382597.0     32520.0   349493.0    83700.0             no         no
# 2     203784.0     19241.0   266026.0    64700.0             no         no
# 3     194673.0     19872.0   526186.0   316000.0             no         no
# 4     182795.0     39510.0   231839.0    97200.0             no         no
#
#   newcomer_to_fortune_500 global_500
# 0                      no        NaN
# 1                      no        NaN
# 2                      no        NaN
# 3                      no        NaN
# 4                      no        NaN

# %%
# Generate list of cities that need coordinates
city_list = final_df['headquarters_city']

# Remove empty values
city_list = city_list.dropna()
city_list
# Out:
# 0        Bentonville
# 1             Irving
# 2          San Ramon
# 3              Omaha
# 4          Cupertino
#             ...
# 4495        New York
# 4496    Redwood City
# 4497      Hartsville
# 4498     Santa Clara
# 4499      Menlo Park
# Name: headquarters_city, Length: 4500, dtype: object

# %%
# Generate list of cities that need coordinates
state_list = final_df['headquarters_state']

# Remove empty values
state_list = state_list.dropna()
state_list
# Out:
# 0       AR
# 1       TX
# 2       CA
# 3       NE
# 4       CA
#         ..
# 4495    NY
# 4496    CA
# 4497    SC
# 4498    CA
# 4499    CA
# Name: headquarters_state, Length: 4500, dtype: object

# %%
# Zip city and state together for API request
city_state_zip = zip(city_list, state_list)
city_state = list(city_state_zip)
print(city_state)
# Out:
# [('Bentonville', 'AR'), ('Irving', 'TX'), ('San Ramon', 'CA'), ('Omaha', 'NE'), ('Cupertino', 'CA'), ('Detroit', 'MI'), ('Houston', 'TX'), ('Fairfield', 'CT'), ('Dearborn', 'MI'), ('Woonsocket', 'RI'), ('San Francisco', 'CA'), ('Dallas', 'TX'), ('San Antonio', 'TX'), ('Minnetonka', 'MN'), ('New York', 'NY'), ('Chesterbrook', 'PA'), ('Washington', 'DC'), ('Issaquah', 'WA'), ('Palo Alto', 'CA'), ('Cincinnati', 'OH'), ('New York', 'NY'), ('St. Louis', 'MO'), ('Charlotte', 'NC'), ('Armonk', 'NY'), ('Findlay', 'OH'), ('Dublin', 'OH'), ('Chicago', 'IL'), ('New York', 'NY'), ('Seattle', 'WA'), ('San Francisco', 'CA'), ('Redmond', 'WA'), ('Cincinnati', 'OH'), ('Atlanta', 'GA'), ('Chicago', 'IL'), ('Deerfield', 'IL'), ('Minneapolis', 'MN'), ('New Brunswick', 'NJ'), ('Indianapolis', 'IN'), ('New York', 'NY'), ('Mountain View', 'CA'), ('Bloomington', 'IL'), ('McLean', 'VA'), ('Philadelphia', 'PA'), ('Purchase', 'NY'), ('Hartford', 'CT'), ('New York', 'NY'), ('Atlanta', 'GA'), ('Midland', 'MI'), ('Hartford', 'CT'), ('Mooresville', 'NC'), ('Houston', 'TX'), ('Santa Clara', 'CA'), ('Dallas', 'TX'), ('Peoria', 'IL'), ('Newark', 'NJ'), ('New York', 'NY'), ('Burbank', 'CA'), ('Louisville', 'KY'), ('Houston', 'TX'), ('San Jose', 'CA'), ('Houston', 'TX'), ('Santa Ana', 'CA'), ('Atlanta', 'GA'), ('Bethesda', 'MD'), ('Memphis', 'TN'), ('Milwaukee', 'WI'), ('Houston', 'TX'), ('Miami', 'FL'), ('Inver Grove Heights', 'MN'), ('Fort Worth', 'TX'), ('Kenilworth', 'NJ'), ('Richfield', 'MN'), ('Atlanta', 'GA'), ('Morris Township', 'NJ'), ('Nashville', 'TN'), ('New York', 'NY'), ('San Antonio', 'TX'), ('Boston', 'MA'), ('Chicago', 'IL'), ('New York', 'NY'), ('Redwood City', 'CA'), ('New York', 'NY'), ('Springdale', 'AR'), ('Pleasanton', 'CA'), ('Columbus', 'OH'), ('Moline', 'IL'), ('Wilmington', 'DE'), ('New York', 'NY'), ('Northbrook', 'IL'), ('Bloomfield', 'CT'), ('Deerfield', 'IL'), ('New York', 'NY'), ('New York', 'NY'), ('Springfield', 'MA'), ('El Segundo', 'CA'), ('Houston', 'TX'), ('New York', 'NY'), ('St. Paul', 'MN'), ('Hoffman Estates', 'IL'), ('Falls Church', 'VA'), ('Lakeland', 'FL'), ('New York', 'NY'), ('Framingham', 'MA'), ('New York', 'NY'), ('Cincinnati', 'OH'), ('Beaverton', 'OR'), ('Clearwater', 'FL'), ('Phoenix', 'AZ'), ('Milwaukee', 'WI'), ('Oak Brook', 'IL'), ('Chicago', 'IL'), ('New York', 'NY'), ('San Diego', 'CA'), ('Memphis', 'TN'), ('Houston', 'TX'), ('Charlotte', 'NC'), ('Camp Hill', 'PA'), ('Foster City', 'CA'), ('Houston', 'TX'), ('St. Louis', 'MO'), ('Hopkinton', 'MA'), ('San Antonio', 'TX'), ('Omaha', 'NE'), ('Falls Church', 'VA'), ('New York', 'NY'), ('McLean', 'VA'), ('Houston', 'TX'), ('Rosemont', 'IL'), ('Waltham', 'MA'), ('New York', 'NY'), ('Centennial', 'CO'), ('Columbus', 'GA'), ('Framingham', 'MA'), ('Abbott Park', 'IL'), ('Franklin', 'TN'), ('Irving', 'TX'), ('Phoenix', 'AZ'), ('Minneapolis', 'MN'), ('Charlotte', 'NC'), ('Irving', 'TX'), ('New York', 'NY'), ('Oklahoma City', 'OK'), ('Norwalk', 'CT'), ('Milwaukee', 'WI'), ('Thousand Oaks', 'CA'), ('North Chicago', 'IL'), ('Washington', 'DC'), ('Benton Harbor', 'MI'), ('Parsippany', 'NJ'), ('Dallas', 'TX'), ('Indianapolis', 'IN'), ('Oklahoma City', 'OK'), ('Mayfield Village', 'OH'), ('Columbus', 'IN'), ('New York', 'NY'), ('Fort Lauderdale', 'FL'), ('Menomonee Falls', 'WI'), ('Bellevue', 'WA'), ('Goodlettsville', 'TN'), ('Hartford', 'CT'), ('Dallas', 'TX'), ('The Woodlands', 'TX'), ('Atlanta', 'GA'), ('Eden Prairie', 'MN'), ('Northfield', 'IL'), ('Akron', 'OH'), ('Houston', 'TX'), ('Monroe', 'LA'), ('Richmond', 'VA'), ('Dallas', 'TX'), ('Minneapolis', 'MN'), ('San Jose', 'CA'), ('Omaha', 'NE'), ('Southfield', 'MI'), ('Livonia', 'MI'), ('Pittsburgh', 'PA'), ('Bloomfield Hills', 'MI'), ('Arlington', 'VA'), ('New York', 'NY'), ('Waltham', 'MA'), ('Waltham', 'MA'), ('San Francisco', 'CA'), ('Juno Beach', 'FL'), ('Columbus', 'OH'), ('Deerfield', 'IL'), ('St. Louis', 'MO'), ('Seattle', 'WA'), ('San Francisco', 'CA'), ('New York', 'NY'), ('Boise', 'ID'), ('St. Petersburg',  ...

# %%
# Empty lists for holding data
lat = []
lng = []
city = []
skip_list = []

# %%
location = geolocator.geocode(city_state[0])
location.latitude
# Out:
# 36.3728538

# %%
# Record coordinates for each city
# This cell takes a LONG TIME to run

for i in city_state:
    if i in city or i == None or i in skip_list:
        pass
    else:
        try:
            location = geolocator.geocode(i)
            lat.append(location.latitude)
            lng.append(location.longitude)
            city.append(i)
            print(f'Adding coordinates for {i} to list')
            time.sleep(1)
        except:
            print(f'Skpping {i}')
            skip_list.append(i)
            time.sleep(1)
# Out:
# Adding coordinates for ('Bentonville', 'AR') to list
# Adding coordinates for ('Irving', 'TX') to list
# Adding coordinates for ('San Ramon', 'CA') to list
# Adding coordinates for ('Omaha', 'NE') to list
# Adding coordinates for ('Cupertino', 'CA') to list
# Adding coordinates for ('Detroit', 'MI') to list
# Adding coordinates for ('Houston', 'TX') to list
# Adding coordinates for ('Fairfield', 'CT') to list
# Adding coordinates for ('Dearborn', 'MI') to list
# Adding coordinates for ('Woonsocket', 'RI') to list
# Adding coordinates for ('San Francisco', 'CA') to list
# Adding coordinates for ('Dallas', 'TX') to list
# Adding coordinates for ('San Antonio', 'TX') to list
# Adding coordinates for ('Minnetonka', 'MN') to list
# Adding coordinates for ('New York', 'NY') to list
# Adding coordinates for ('Chesterbrook', 'PA') to list
# Adding coordinates for ('Washington', 'DC') to list
# Adding coordinates for ('Issaquah', 'WA') to list
# Adding coordinates for ('Palo Alto', 'CA') to list
# Adding coordinates for ('Cincinnati', 'OH') to list
# Adding coordinates for ('St. Louis', 'MO') to list
# Adding coordinates for ('Charlotte', 'NC') to list
# Adding coordinates for ('Armonk', 'NY') to list
# Adding coordinates for ('Findlay', 'OH') to list
# Adding coordinates for ('Dublin', 'OH') to list
# Adding coordinates for ('Chicago', 'IL') to list
# Adding coordinates for ('Seattle', 'WA') to list
# Adding coordinates for ('Redmond', 'WA') to list
# Adding coordinates for ('Atlanta', 'GA') to list
# Adding coordinates for ('Deerfield', 'IL') to list
# Adding coordinates for ('Minneapolis', 'MN') to list
# Adding coordinates for ('New Brunswick', 'NJ') to list
# Adding coordinates for ('Indianapolis', 'IN') to list
# Adding coordinates for ('Mountain View', 'CA') to list
# Adding coordinates for ('Bloomington', 'IL') to list
# Adding coordinates for ('McLean', 'VA') to list
# Adding coordinates for ('Philadelphia', 'PA') to list
# Adding coordinates for ('Purchase', 'NY') to list
# Adding coordinates for ('Hartford', 'CT') to list
# Adding coordinates for ('Midland', 'MI') to list
# Adding coordinates for ('Mooresville', 'NC') to list
# Adding coordinates for ('Santa Clara', 'CA') to list
# Adding coordinates for ('Peoria', 'IL') to list
# Adding coordinates for ('Newark', 'NJ') to list
# Adding coordinates for ('Burbank', 'CA') to list
# Adding coordinates for ('Louisville', 'KY') to list
# Adding coordinates for ('San Jose', 'CA') to list
# Adding coordinates for ('Santa Ana', 'CA') to list
# Adding coordinates for ('Bethesda', 'MD') to list
# Adding coordinates for ('Memphis', 'TN') to list
# Adding coordinates for ('Milwaukee', 'WI') to list
# Adding coordinates for ('Miami', 'FL') to list
# Adding coordinates for ('Inver Grove Heights', 'MN') to list
# Adding coordinates for ('Fort Worth', 'TX') to list
# Adding coordinates for ('Kenilworth', 'NJ') to list
# Adding coordinates for ('Richfield', 'MN') to list
# Adding coordinates for ('Morris Township', 'NJ') to list
# Adding coordinates for ('Nashville', 'TN') to list
# Adding coordinates for ('Boston', 'MA') to list
# Adding coordinates for ('Redwood City', 'CA') to list
# Adding coordinates for ('Springdale', 'AR') to list
# Adding coordinates for ('Pleasanton', 'CA') to list
# Adding coordinates for ('Columbus', 'OH') to list
# Adding coordinates for ('Moline', 'IL') to list
# Adding coordinates for ('Wilmington', 'DE') to list
# Adding coordinates for ('Northbrook', 'IL') to list
# Adding coordinates for ('Bloomfield', 'CT') to list
# Adding coordinates for ('Springfield', 'MA') to list
# Adding coordinates for ('El Segundo', 'CA') to list
# Adding coordinates for ('St. Paul', 'MN') to list
# Adding coordinates for ('Hoffman Estates', 'IL') to list
# Adding coordinates for ('Falls Church', 'VA') to list
# Adding coordinates for ('Lakeland', 'FL') to list
# Adding coordinates for ('Framingham', 'MA') to list
# Adding coordinates for ('Beaverton', 'OR') to list
# Adding coordinates for ('Clearwater', 'FL') to list
# Adding coordinates for ('Phoenix', 'AZ') to list
# Adding coordinates for ('Oak Brook', 'IL') to list
# Adding coordinates for ('San Diego', 'CA') to list
# Adding coordinates for ('Camp Hill', 'PA') to list
# Adding coordinates for ('Foster City', 'CA') to list
# Adding coordinates for ('Hopkinton', 'MA') to list
# Adding coordinates for ('Rosemont', 'IL') to list
# Adding coordinates for ('Waltham', 'MA') to list
# Skpping ('Centennial', 'CO')
# Adding coordinates for ('Columbus', 'GA') to list
# Adding coordinates for ('Abbott Park', 'IL') to list
# Adding coordinates for ('Franklin', 'TN') to list
# Adding coordinates for ('Oklahoma City', 'OK') to list
# Adding coordinates for ('Norwalk', 'CT') to list
# Adding coordinates for ('Thousand Oaks', 'CA') to list
# Adding coordinates for ('North Chicago', 'IL') to list
# Adding coordinates for ('Benton Harbor', 'MI') to list
# Adding coordinates for ('Parsippany', 'NJ') to list
# Adding coordinates for ('Mayfield Village', 'OH') to list
# Adding coordinates for ('Columbus', 'IN') to list
# Adding coordinates for ('Fort Lauderdale', 'FL') to list
# Adding coordinates for ('Menomonee Falls', 'WI') to list
# Adding coordinates for ('Bellevue', 'WA') to list
# Adding coordinates for ('Goodlettsville', 'TN') to list
# Adding coordinates for ('The Woodlands', 'TX') to list
# Adding coordinates for ('Eden Prairie', 'MN') to list
# Adding coordinates for ('Northfield', 'IL') to list
# Adding coordinates for ('Akron', 'OH') to list
# Adding coordinates for ('Monroe', 'LA') to list
# Adding coordinates for ('Richmond', 'VA') to list
# Adding coordinates for ('Southfield', 'MI') to list
# Adding coordinates for ('Livonia', 'MI') to list
# Adding coordinates for ('Pittsburgh', 'PA') to list
# Adding coordinates for ('Bloomfield Hills', 'MI') to list
# Adding coordinates for ('Arlington', 'VA') to list
# Adding coordinates for ('Juno Beach', 'FL') to list
# Adding coordinates for ('Boise', 'ID') to list
# Adding coordinates for ('St. Petersburg', 'FL') to list
# Adding coordinates for ('Boca Raton', 'FL') to list
# Adding coordinates for ('Princeton', 'NJ') to list
# Adding coordinates for ('Glenview', 'IL') to list
# Adding coordinates for ('El Dorado', 'AR') to list
# Adding coordinates for ('Arden Hills', 'MN') to list
# Adding coordinates for ('El Paso', 'TX') to list
# Adding coordinates for ('Irvine', 'CA') to list
# Adding coordinates for ('Englewood', 'CO') to list
# Adding coordinates for ('Las Vegas', 'NV') to list
# Adding coordinates for ('Battle Creek', 'MI') to list
# Adding coordinates for ('Austin', 'TX') to list
# Adding coordinates for ('Warren', 'NJ') to list
# Adding coordinates for ('Woodland Hills', 'CA') to list
# Adding coordinates for ('Providence', 'RI') to list
# Adding coordinates for ('Fremont', 'CA') to list
# Adding coordinates for ('Radnor', 'PA') to list
# Adding coordinates for ('Rosemead', 'CA') to list
# Adding coordinates for ('Cleveland', 'OH') to list
# Skpping ('Denver', 'CO')
# Adding coordinates for ('Tampa', 'FL') to list
# Adding coordinates for ('Tulsa', 'OK') to list
# Adding coordinates for ('Pasadena', 'CA') to list
# Adding coordinates for ('Jacksonville', 'FL') to list
# Adding coordinates for ('New Orleans', 'LA') to list
# Adding coordinates for ('Menlo Park', 'CA') to list
# Adding coordinates for ('Wayne', 'NJ') to list
# Adding coordinates for ('Greensboro', 'NC') to list
# Adding coordinates for ('Danbury', 'CT') to list
# Adding coordinates for ('Plano', 'TX') to list
# Adding coordinates for ('Roseland', 'NJ') to list
# Adding coordinates for ('Vernon Hills', 'IL') to list
# Adding coordinates for ('Norfolk', 'VA') to list
# Adding coordinates for ('Allentown', 'PA') to list
# Adding coordinates for ('Salt Lake City', 'UT') to list
# Adding coordinates for ('Union', 'NJ') to list
# Adding coordinates for ('New Britain', 'CT') to list
# Adding coordinates for ('Dublin', 'CA') to list
# Adding coordinates for ('Chesterfield', 'MO') to list
# Adding coordinates for ('Lisle', 'IL') to list
# Adding coordinates for ('Chattanooga', 'TN') to list
# Adding coordinates for ('Matthews', 'NC') to list
# Adding coordinates for ('Des Moines', 'IA') to list
# Adding coordinates for ('Los Angeles', 'CA') to list
# Adding coordinates for ('Melville', 'NY') to list
# Adding coordinates for ('Teaneck', 'NJ') to list
# Adding coordinates for ('Lake Forest', 'IL') to list
# Adding coordinates for ('Winston-Salem', 'NC') to list
# Adding coordinates for ('Norcross', 'GA') to list
# Adding coordinates for ('Roanoke', 'VA') to list
# Adding coordinates for ('Duluth', 'GA') to list
# Adding coordinates for ('Corning', 'NY') to list
# Adding coordinates for ('Cambridge', 'MA') to list
# Adding coordinates for ('Kalamazoo', 'MI') to list
# Adding coordinates for ('Long Beach', 'CA') to list
# Adding coordinates for ('Portland', 'OR') to list
# Adding coordinates for ('Riverwoods', 'IL') to list
# Adding coordinates for ('Kingsport', 'TN') to list
# Adding coordinates for ('Mechanicsville', 'VA') to list
# Adding coordinates for ('Austin', 'MN') to list
# Adding coordinates for ('Grapevine', 'TX') to list
# Adding coordinates for ('Auburn Hills', 'MI') to list
# Adding coordinates for ('Stamford', 'CT') to list
# Adding coordinates for ('Plymouth', 'MN') to list
# Adding coordinates for ('King of Prussia', 'PA') to list
# Adding coordinates for ('Orlando', 'FL') to list
# Adding coordinates for ('Fort Wayne', 'IN') to list
# Adding coordinates for ('Chesapeake', 'VA') to list
# Adding coordinates for ('Broomfield', 'CO') to list
# Adding coordinates for ('Taylor', 'MI') to list
# Adding coordinates for ('San Mateo', 'CA') to list
# Adding coordinates for ('Franklin Lakes', 'NJ') to list
# Adding coordinates for ('Camden', 'NJ') to list
# Adding coordinates for ('Van Buren Township', 'MI') to list
# Adding coordinates for ('Brentwood', 'TN') to list
# Adding coordinates for ('Downers Grove', 'IL') to list
# Adding coordinates for ('South San Francisco', 'CA') to list
# Adding coordinates for ('Federal Way', 'WA') to list
# Adding coordinates for ('Madison', 'WI') to list
# Adding coordinates for ('Grand Rapids', 'MI') to list
# Adding coordinates for ('Calhoun', 'GA') to list
# Adding coordinates for ('Schaumburg', 'IL') to list
# Adding coordinates for ('Westlake', 'OH') to list
# Adding coordinates for ('Summit', 'NJ') to list
# Adding coordinates for ('Covington', 'KY') to list
# Adding coordinates for ('Madison', 'NJ') to list
# Adding coordinates for ('Hershey', 'PA') to list
# Adding coordinates for ('Westport', 'CT') to list
# Skpping ('Marlborough', 'MA')
# Adding coordinates for ('Greenwood Village', 'CO') to list
# Adding coordinates for ('Springfield', 'MO') to list
# Adding coordinates for ('Ankeny', 'IA') to list
# Adding coordinates for ('Jackson', 'MI') to list
# Adding coordinates for ('Greenwich', 'CT') to list
# Adding coordinates for ('Newport Beach', 'CA') to list
# Adding coordinates for ('Newport News', 'VA') to list
# Adding coordinates for ('Beverly Hills', 'CA') to list
# Adding coordinates for ('Coraopolis', 'PA') to list
# Adding coordinates for ('Oshkosh', 'WI') to list
# Adding coordinates for ('Wichita', 'KS') to list
# Adding coordinates for ('Perrysburg', 'OH') to list
# Adding coordinates for ('Little Rock', 'AR') to list
# Adding coordinates for ('Cary', 'NC') to list
# Adding coordinates for ('Milpitas', 'CA') to list
# Adding coordinates for ('Maumee', 'OH') to list
# Adding coordinates for ('Overland Park', 'KS') to list
# Adding coordinates for ('West Chester', 'OH') to list
# Adding coordinates for ('Shawnee Mission', 'KS') to list
# Adding coordinates for ('Merrillville', 'IN') to list
# Adding coordinates for ('Bethpage', 'NY') to list
# Adding coordinates for ('Lansing', 'MI') to list
# Adding coordinates for ('Des Peres', 'MO') to list
# Adding coordinates for ('Glendale', 'CA') to list
# Adding coordinates for ('Sunnyvale', 'CA') to list
# Adding coordinates for ('Silver Spring', 'MD') to list
# Adding coordinates for ('Lowell', 'AR') to list
# Adding coordinates for ('Erie', 'PA') to list
# Adding coordinates for ('Burlington', 'NC') to list
# Adding coordinates for ('Highland Heights', 'KY') to list
# Adding coordinates for ('Santa Monica', 'CA') to list
# Adding coordinates for ('Long Island City', 'NY') to list
# Adding coordinates for ('Ann Arbor', 'MI') to list
# Adding coordinates for ('Westchester', 'IL') to list
# Adding coordinates for ('Orrville', 'OH') to list
# Adding coordinates for ('Oakland', 'CA') to list
# Adding coordinates for ('Fort Mill', 'SC') to list
# Adding coordinates for ('Troy', 'MI') to list
# Adding coordinates for ('Los Gatos', 'CA') to list
# Adding coordinates for ('Durham', 'NC') to list
# Adding coordinates for ('Birmingham', 'AL') to list
# Adding coordinates for ('Medford', 'OR') to list
# Adding coordinates for ('Wallingford', 'CT') to list
# Adding coordinates for ('Suwanee', 'GA') to list
# Adding coordinates for ('Tempe', 'AZ') to list
# Adding coordinates for ('Toledo', 'OH') to list
# Adding coordinates for ('Farmington', 'CT') to list
# Adding coordinates for ('Morris Plains', 'NJ') to list
# Adding coordinates for ('Lincolnshire', 'IL') to list
# Adding coordinates for ('Estero', 'FL') to list
# Adding coordinates for ('Byron Center', 'MI') to list
# Adding coordinates for ('Bannockburn', 'IL') to list
# Adding coordinates for ('Victor', 'NY') to list
# Adding coordinates for ('Warsaw', 'IN') to list
# Adding coordinates for ('Kennett Square', 'PA') to list
# Adding coordinates for ('Merriam', 'KS') to list
# Adding coordinates for ('Itasca', 'IL') to list
# Adding coordinates for ('Glen Allen', 'VA') to list
# Adding coordinates for ('Cedar Rapids', 'IA') to list
# Adding coordinates for ('Brookfield', 'WI') to list
# Adding coordinates for ('Reston', 'VA') to list
# Adding coordinates for ('Fairfield', 'OH') to list
# Adding coordinates for ('Burlington', 'NJ') to list
# Adding coordinates for ('Round Rock', 'TX') to list
# Adding coordinates for ('Hoboken', 'NJ') to list
# Adding coordinates for ('Arlington', 'TX') to list
# Adding coordinates for ('Melbourne', 'FL') to list
# Adding coordinates for ('Tysons', 'VA') to list
# Adding coordinates for ('Mahwah', 'NJ') to list
# Adding coordinates for ('Evansville', 'IN') to list
# Adding coordinates for ('Rye', 'NY') to list
# Adding coordinates for ('Buffalo', 'NY') to list
# Adding coordinates for ('Clayton', 'MO') to list
# Adding coordinates for ('Horsham', 'PA') to list
# Adding coordinates for ('Secaucus', 'NJ') to list
# Adding coordinates for ('Elkhart', 'IN') to list
# Adding coordinates for ('Everett', 'WA') to list
# Adding coordinates for ('Coral Gables', 'FL') to list
# Adding coordinates for ('Rolling Meadows', 'IL') to list
# Adding coordinates for ('Florham Park', 'NJ') to list
# Adding coordinates for ('Bolingbrook', 'IL') to list
# Adding coordinates for ('Tarrytown', 'NY') to list
# Adding coordinates for ('Scottsdale', 'AZ') to list
# Adding coordinates for ('Medina', 'MN') to list
# Adding coordinates for ('Westborough', 'MA') to list
# Adding coordinates for ('Yardley', 'PA') to list
# Adding coordinates for ('Raleigh', 'NC') to list
# Adding coordinates for ('West Palm Beach', 'FL') to list
# Skpping ('Burlington', 'MA')
# Adding coordinates for ('Herndon', 'VA') to list
# Skpping ('Norwood', 'MA')
# Adding coordinates for ('Westlake', 'TX') to list
# Adding coordinates for ('Hickory', 'NC') to list
# Adding coordinates for ('Johnston', 'RI') to list
# Adding coordinates for ('New Braunfels', 'TX') to list
# Adding coordinates for ('North Kansas City', 'MO') to list
# Adding coordinates for ('Palm Beach Gardens', 'FL') to list
# Adding coordinates for ('Canonsburg', 'PA') to list
# Skpping ('Westminster', 'CO')
# Adding coordinates for ('Dania Beach', 'FL') to list
# Adding coordinates for ('Fort Washington', 'PA') to list
# Adding coordinates for ('Baltimore', 'MD') to list
# Adding coordinates for ('Sunny Isles Beach', 'FL') to list
# Adding coordinates for ('Hunt Valley', 'MD') to list
# Adding coordinates for ('Katy', 'TX') to list
# Adding coordinates for ('Winona', 'MN') to list
# Skpping ('Wilmington', 'MA')
# Adding coordinates for ('Bismarck', 'ND') to list
# Adding coordinates for ('Mechanicsburg', 'PA') to list
# Adding coordinates for ('Sarasota', 'FL') to list
# Adding coordinates for ('Medina', 'OH') to list
# Adding coordinates for ('Pawtucket', 'RI') to list
# Adding coordinates for ('Conshohocken', 'PA') to list
# Adding coordinates for ('Reno', 'NV') to list
# Adding coordinates for ('Midland', 'TX') to list
# Adding coordinates for ('Reynoldsburg', 'OH') to list
# Adding coordinates for ('Spring', 'TX') to list
# Adding coordinates for ('Rahway', 'NJ') to list
# Adding coordinates for ('Ashburn', 'VA') to list
# Adding coordinates for ('Chandler', 'AZ') to list
# Adding coordinates for ('Plantation', 'FL') to list
# Adding coordinates for ('Mentor', 'OH') to list
# Adding coordinates for ('Sumner', 'WA') to list
# Adding coordinates for ('Manhattan Beach', 'CA') to list
# Adding coordinates for ('Hartsville', 'SC') to list

# %%
# Create dataframe for merging
city_df = pd.DataFrame({
    'city_state': city,
    'latitude': lat,
    'longitude': lng
})

# %%
# Split city and state to separate columns
city_merge = []
state_merge = []

for i in range(len(city_df)):
    city_merge.append(city_df['city_state'][i][0])
    state_merge.append(city_df['city_state'][i][1])

# %%
# Create dataframe for merging
merge_city_df = pd.DataFrame({
    'headquarters_city': city_merge,
    'headquarters_state': state_merge,
    'latitude': lat,
    'longitude': lng
})

# %%
# Merge coordinates to the col_rename_df_updated
merged_col_rename_df_updated = final_df.merge(merge_city_df,on=['headquarters_city','headquarters_state'], how='left')
merged_col_rename_df_updated
# Out:
#                            name  rank  year  \
# 0                       Walmart     1  2015
# 1                   Exxon Mobil     2  2015
# 2                       Chevron     3  2015
# 3            Berkshire Hathaway     4  2015
# 4                         Apple     5  2015
# ...                         ...   ...   ...
# 4495                        KKR   496  2023
# 4496                    Equinix   497  2023
# 4497            Sonoco Products   498  2023
# 4498                 ServiceNow   499  2023
# 4499  Robert Half International   500  2023
#
#                                       industry             sector  \
# 0                        General Merchandisers          Retailing
# 1                           Petroleum Refining             Energy
# 2                           Petroleum Refining             Energy
# 3     Insurance: Property and Casualty (Stock)         Financials
# 4                  Computers, Office Equipment         Technology
# ...                                        ...                ...
# 4495                                Securities         Financials
# 4496                               Real Estate         Financials
# 4497                     Packaging, Containers          Materials
# 4498                         Computer Software         Technology
# 4499                            Temporary Help  Business Services
#
#      headquarters_state headquarters_city  market_value_mil  revenue_mil  \
# 0                    AR       Bentonville          265344.0     485651.0
# 1                    TX            Irving          356549.0     382597.0
# 2                    CA         San Ramon          197381.0     203784.0
# 3                    NE             Omaha          357344.0     194673.0
# 4                    CA         Cupertino          724773.0     182795.0
# ...                 ...               ...               ...          ...
# 4495                 NY          New York           45225.0       7273.0
# 4496                 CA      Redwood City           66873.0       7263.0
# 4497                 SC        Hartsville            5975.0       7251.0
# 4498                 CA       Santa Clara           94338.0       7245.0
# 4499                 CA        Menlo Park            8677.0       7238.0
#
#       profit_mil  asset_mil  employees founder_is_ceo female_ceo  \
# 0        16363.0   203706.0  2200000.0             no         no
# 1        32520.0   349493.0    83700.0             no         no
# 2        19241.0   266026.0    64700.0             no         no
# 3        19872.0   526186.0   316000.0             no         no
# 4        39510.0   231839.0    97200.0             no         no
# ...          ...        ...        ...            ...        ...
# 4495       841.0   277077.0     4150.0             no         no
# 4496       704.0    30311.0    12097.0             no         no
# 4497       466.0     7053.0    22000.0             no         no
# 4498       325.0    13299.0    20433.0             no         no
# 4499       658.0     2965.0    16300.0             no         no
#
#      newcomer_to_fortune_500 global_500   latitude   longitude
# 0                         no        NaN  36.372854  -94.208817
# 1                         no        NaN  32.829518  -96.944218
# 2                         no        NaN  37.764802 -121.954439
# 3                         no        NaN  41.258746  -95.938376
# 4                         no        NaN  37.322893 -122.032290
# ...                      ...        ...        ...         ...
# 4495                      no         no  40.712728  -74.006015
# 4496                      no         no  37.486324 -122.232523
# 4497                     yes         no  34.374043  -80.073401
# 4498                     yes         no  37.233325 -121.684635
# 4499                      no         no  37.451967 -122.177992
#
# [4500 rows x 18 columns]

# %%
# Generate list of states that need coordinates
state_list = []


for i in range(len(merged_col_rename_df_updated)):
    if merged_col_rename_df_updated['latitude'][i] > 0 or merged_col_rename_df_updated['latitude'][i] < 0:
        pass
    else:
        item = merged_col_rename_df_updated['headquarters_state'][i]
        state_list.append(item)
# Out:
# ['CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'MA',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'CO',
#  'CO',
#  'MA',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'MA',
#  'MA',
#  'CO',
#  'MA',
#  'CO',
#  'CO',
#  'CO']

# %%
# Remove duplicates from the list
state_list = list(set(state_list))
state_list
# Out:
# ['MA', 'CO']

# %%
# Specify the state name for errors so API isn't confused
for i in range(len(state_list)):
    if state_list[i] == 'MA':
        state_list[i] = 'Massachusetts'
    elif state_list[i] == 'CO':
        state_list[i] = 'Colorado'

state_list
# Out:
# ['Massachusetts', 'Colorado']

# %%
# Generate empty lists to hold data
lat = []
lng = []
state = []

# %%
# Record coordinates for each state, when city is unavailable
for i in state_list:
    if i in state or i == None:
        pass
    else:
        try:
            location = geolocator.geocode(i)
            lat.append(location.latitude)
            lng.append(location.longitude)
            state.append(i)
            print(f'Adding coordinates for {i} to list')
            time.sleep(1)
        except:
            print(f'Skpping {i}')
# Out:
# Adding coordinates for Massachusetts to list
# Adding coordinates for Colorado to list

# %%
# Generate dataframe of state coordinates
state_df = pd.DataFrame({
    'headquarters_state': state,
    'latitude': lat,
    'longitude': lng
})
state_df
# Out:
#   headquarters_state   latitude   longitude
# 0      Massachusetts  42.378877  -72.032366
# 1           Colorado  38.725178 -105.607716

# %%
# Revert state names back to original
for i in range(len(state_df)):
    if state_df['headquarters_state'][i] == 'Massachusetts':
        state_df['headquarters_state'][i] = 'MA'
    elif state_df['headquarters_state'][i] == 'Colorado':
        state_df['headquarters_state'][i] = 'CO'

state_df
# Out:
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\2878882674.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['headquarters_state'][i] = 'MA'
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\2878882674.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   state_df['headquarters_state'][i] = 'CO'
#   headquarters_state   latitude   longitude
# 0                 MA  42.378877  -72.032366
# 1                 CO  38.725178 -105.607716

# %%
# Add coordinates to the merged dataframe
try:
    for i in range(len(merged_col_rename_df_updated)):
        if merged_col_rename_df_updated['latitude'][i] > 0 or merged_col_rename_df_updated['latitude'][i] < 0:
            pass
        else:
            merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
            merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
except:
    pass
# Out:
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# ...
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:7: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['latitude'][i] = state_df['latitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]
# C:\Users\atjoh\AppData\Local\Temp\ipykernel_12884\1829829518.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   merged_col_rename_df_updated['longitude'][i] = state_df['longitude'].loc[state_df['headquarters_state'] == merged_col_rename_df_updated['headquarters_state'][i]]

# %%
# Export
export = merged_col_rename_df_updated[['name','headquarters_city','headquarters_state','latitude','longitude']]

# %%
# Export data
export.to_csv('Resources/fortune_coordinates_new.csv', index=False)
