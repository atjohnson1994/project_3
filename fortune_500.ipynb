# %%
import pandas as pd

# %%
fortune_500_data = pd.read_csv('./Resources/use_this_fortune_500.csv')
fortune_500_data
# Out:
#                              name  rank  year                industry  \
# 0      General Motors Corporation     1  1996  Motor Vehicles & Parts
# 1              Ford Motor Company     2  1996  Motor Vehicles & Parts
# 2               Exxon Corporation     3  1996      Petroleum Refining
# 3           Wal-Mart Stores, Inc.     4  1996   General Merchandisers
# 4                      AT&T Corp.     5  1996      Telecommunications
# ...                           ...   ...   ...                     ...
# 13935                         KKR   496  2023              Securities
# 13936                     Equinix   497  2023             Real Estate
# 13937             Sonoco Products   498  2023   Packaging, Containers
# 13938                  ServiceNow   499  2023       Computer Software
# 13939   Robert Half International   500  2023          Temporary Help
#
#                   sector headquarters_state headquarters_city  \
# 0                    NaN                 MI               NaN
# ...

# %%
fortune_500_df = fortune_500_data[["name", "rank", "year", "industry", "sector", "headquarters_state", "headquarters_city", "market_value_mil","revenue_mil","profit_mil","employees"]]

fortune_500_df
# Out:
#                              name  rank  year                industry  \
# 0      General Motors Corporation     1  1996  Motor Vehicles & Parts
# 1              Ford Motor Company     2  1996  Motor Vehicles & Parts
# 2               Exxon Corporation     3  1996      Petroleum Refining
# 3           Wal-Mart Stores, Inc.     4  1996   General Merchandisers
# 4                      AT&T Corp.     5  1996      Telecommunications
# ...                           ...   ...   ...                     ...
# 13935                         KKR   496  2023              Securities
# 13936                     Equinix   497  2023             Real Estate
# 13937             Sonoco Products   498  2023   Packaging, Containers
# 13938                  ServiceNow   499  2023       Computer Software
# 13939   Robert Half International   500  2023          Temporary Help
#
#                   sector headquarters_state headquarters_city  \
# 0                    NaN                 MI               NaN
# ...

# %%
renamed_df = fortune_500_df.rename(columns={"market_value_mil":"market_value_millions", "revenue_mil":"revenue_millions", "profit_mil":"profit_millions"})
renamed_df
# Out:
#                              name  rank  year                industry  \
# 0      General Motors Corporation     1  1996  Motor Vehicles & Parts
# 1              Ford Motor Company     2  1996  Motor Vehicles & Parts
# 2               Exxon Corporation     3  1996      Petroleum Refining
# 3           Wal-Mart Stores, Inc.     4  1996   General Merchandisers
# 4                      AT&T Corp.     5  1996      Telecommunications
# ...                           ...   ...   ...                     ...
# 13935                         KKR   496  2023              Securities
# 13936                     Equinix   497  2023             Real Estate
# 13937             Sonoco Products   498  2023   Packaging, Containers
# 13938                  ServiceNow   499  2023       Computer Software
# 13939   Robert Half International   500  2023          Temporary Help
#
#                   sector headquarters_state headquarters_city  \
# 0                    NaN                 MI               NaN
# ...

# %%
renamed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13940 entries, 0 to 13939
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   13940 non-null  object
#  1   rank                   13940 non-null  int64
#  2   year                   13940 non-null  int64
#  3   industry               13940 non-null  object
#  4   sector                 4500 non-null   object
#  5   headquarters_state     13940 non-null  object
#  6   headquarters_city      7495 non-null   object
#  7   market_value_millions  5185 non-null   float64
#  8   revenue_millions       13940 non-null  float64
#  9   profit_millions        5497 non-null   float64
#  10  employees              4500 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.2+ MB

# %%
final_df = renamed_df.loc[renamed_df["year"]>= 2015]
final_df.reset_index(drop=True,inplace=True)
final_df
# Out:
#                            name  rank  year  \
# 0                       Walmart     1  2015
# 1                   Exxon Mobil     2  2015
# 2                       Chevron     3  2015
# 3            Berkshire Hathaway     4  2015
# 4                         Apple     5  2015
# ...                         ...   ...   ...
# 4495                        KKR   496  2023
# 4496                    Equinix   497  2023
# 4497            Sonoco Products   498  2023
# 4498                 ServiceNow   499  2023
# 4499  Robert Half International   500  2023
#
#                                       industry             sector  \
# 0                        General Merchandisers          Retailing
# 1                           Petroleum Refining             Energy
# 2                           Petroleum Refining             Energy
# 3     Insurance: Property and Casualty (Stock)         Financials
# 4                  Computers, Office Equipment         Technology
# ...

# %%
final_df["market_value_billions"] = round(final_df["market_value_millions"] / 1000, 1)
final_df["revenue_billions"] = round(final_df["revenue_millions"] / 1000, 1)
final_df["profit_billions"] = round(final_df["profit_millions"] /1000, 1)
final_df
# Out:
# C:\Users\tyler\AppData\Local\Temp\ipykernel_4444\2966108783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["market_value_billions"] = round(final_df["market_value_millions"] / 1000, 1)
# C:\Users\tyler\AppData\Local\Temp\ipykernel_4444\2966108783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["revenue_billions"] = round(final_df["revenue_millions"] / 1000, 1)
# C:\Users\tyler\AppData\Local\Temp\ipykernel_4444\2966108783.py:3: SettingWithCopyWarning:
# ...

# %%
final_df.columns
# Out:
# Index(['name', 'rank', 'year', 'industry', 'sector', 'headquarters_state',
#        'headquarters_city', 'market_value_millions', 'revenue_millions',
#        'profit_millions', 'employees', 'market_value_billions',
#        'revenue_billions', 'profit_billions'],
#       dtype='object')

# %%
reorder_df = final_df[['name', 'rank', 'year', 'industry', 'sector', 'headquarters_state',
       'headquarters_city', 'employees', 'market_value_millions', 'market_value_billions', 'revenue_millions', 'revenue_billions',
       'profit_millions', 'profit_billions' 
        ]]
reorder_df
# Out:
#                            name  rank  year  \
# 0                       Walmart     1  2015
# 1                   Exxon Mobil     2  2015
# 2                       Chevron     3  2015
# 3            Berkshire Hathaway     4  2015
# 4                         Apple     5  2015
# ...                         ...   ...   ...
# 4495                        KKR   496  2023
# 4496                    Equinix   497  2023
# 4497            Sonoco Products   498  2023
# 4498                 ServiceNow   499  2023
# 4499  Robert Half International   500  2023
#
#                                       industry             sector  \
# 0                        General Merchandisers          Retailing
# 1                           Petroleum Refining             Energy
# 2                           Petroleum Refining             Energy
# 3     Insurance: Property and Casualty (Stock)         Financials
# 4                  Computers, Office Equipment         Technology
# ...

# %% [markdown]
# LAT & LONG

# %%
lat_log_data = pd.read_csv('./Resources/fortune_coordinates_new.csv')
lat_log_data
# Out:
#                            name headquarters_city headquarters_state  \
# 0                       Walmart       Bentonville                 AR
# 1                   Exxon Mobil            Irving                 TX
# 2                       Chevron         San Ramon                 CA
# 3            Berkshire Hathaway             Omaha                 NE
# 4                         Apple         Cupertino                 CA
# ...                         ...               ...                ...
# 4495                        KKR          New York                 NY
# 4496                    Equinix      Redwood City                 CA
# 4497            Sonoco Products        Hartsville                 SC
# 4498                 ServiceNow       Santa Clara                 CA
# 4499  Robert Half International        Menlo Park                 CA
#
#        latitude   longitude
# 0     36.372854  -94.208817
# 1     32.829518  -96.944218
# 2     37.764802 -121.954439
# ...

# %%
clean_lat_long = lat_log_data[["latitude", "longitude"]]
clean_lat_long
# Out:
#        latitude   longitude
# 0     36.372854  -94.208817
# 1     32.829518  -96.944218
# 2     37.764802 -121.954439
# 3     41.258746  -95.938376
# 4     37.322893 -122.032290
# ...         ...         ...
# 4495  40.712728  -74.006015
# 4496  37.486324 -122.232523
# 4497  42.247015  -77.693881
# 4498  37.233325 -121.684635
# 4499  37.451967 -122.177992
#
# [4500 rows x 2 columns]

# %%
merge_df = pd.concat([reorder_df, clean_lat_long], axis=1)
merge_df
# Out:
#                            name  rank  year  \
# 0                       Walmart     1  2015
# 1                   Exxon Mobil     2  2015
# 2                       Chevron     3  2015
# 3            Berkshire Hathaway     4  2015
# 4                         Apple     5  2015
# ...                         ...   ...   ...
# 4495                        KKR   496  2023
# 4496                    Equinix   497  2023
# 4497            Sonoco Products   498  2023
# 4498                 ServiceNow   499  2023
# 4499  Robert Half International   500  2023
#
#                                       industry             sector  \
# 0                        General Merchandisers          Retailing
# 1                           Petroleum Refining             Energy
# 2                           Petroleum Refining             Energy
# 3     Insurance: Property and Casualty (Stock)         Financials
# 4                  Computers, Office Equipment         Technology
# ...

# %%
merge_df.columns
# Out:
# Index(['name', 'rank', 'year', 'industry', 'sector', 'headquarters_state',
#        'headquarters_city', 'employees', 'market_value_millions',
#        'market_value_billions', 'revenue_millions', 'revenue_billions',
#        'profit_millions', 'profit_billions', 'name', 'headquarters_city',
#        'headquarters_state', 'latitude', 'longitude'],
#       dtype='object')

# %%
reorder_df_2 = merge_df[['name', 'rank', 'year', 'industry', 'sector', 'headquarters_state',
       'headquarters_city','latitude', 'longitude','employees', 'market_value_millions',
       'market_value_billions', 'revenue_millions', 'revenue_billions',
       'profit_millions', 'profit_billions']]
reorder_df_2
# Out:
#                            name  rank  year  \
# 0                       Walmart     1  2015
# 1                   Exxon Mobil     2  2015
# 2                       Chevron     3  2015
# 3            Berkshire Hathaway     4  2015
# 4                         Apple     5  2015
# ...                         ...   ...   ...
# 4495                        KKR   496  2023
# 4496                    Equinix   497  2023
# 4497            Sonoco Products   498  2023
# 4498                 ServiceNow   499  2023
# 4499  Robert Half International   500  2023
#
#                                       industry             sector  \
# 0                        General Merchandisers          Retailing
# 1                           Petroleum Refining             Energy
# 2                           Petroleum Refining             Energy
# 3     Insurance: Property and Casualty (Stock)         Financials
# 4                  Computers, Office Equipment         Technology
# ...

# %%
reorder_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4500 non-null   object
#  1   rank                   4500 non-null   int64
#  2   year                   4500 non-null   int64
#  3   industry               4500 non-null   object
#  4   sector                 4500 non-null   object
#  5   headquarters_state     4500 non-null   object
#  6   headquarters_city      4500 non-null   object
#  7   latitude               4500 non-null   float64
#  8   longitude              4500 non-null   float64
#  9   employees              4500 non-null   float64
#  10  market_value_millions  4247 non-null   float64
#  11  market_value_billions  4247 non-null   float64
#  12  revenue_millions       4500 non-null   float64
#  13  revenue_billions       4500 non-null   float64
# ...

# %%
#reorder_df_2.to_csv("C:/School/Homework/Project 3/project_3/final_data.csv", index=False)
